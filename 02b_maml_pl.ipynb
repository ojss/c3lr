# %%
import logging
import warnings 

import higher
import pytorch_lightning as pl
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchmetrics

from pytorch_lightning import Trainer
from pytorch_lightning.callbacks import LearningRateMonitor, ModelCheckpoint
from pytorch_lightning.loggers import WandbLogger, TensorBoardLogger
from pytorch_lightning.metrics.functional import accuracy
from torchmeta.datasets.helpers import omniglot
from torchmeta.utils.data import BatchMetaDataLoader

# %%
logger = logging.getLogger(__name__)

# %%
class ConvolutionalNeuralNetwork(nn.Module):
    def __init__(self, in_channels, out_features, hidden_size=64):
        super(ConvolutionalNeuralNetwork, self).__init__()
        self.in_channels = in_channels
        self.out_features = out_features
        self.hidden_size = hidden_size

        self.features = nn.Sequential(
            self.conv3x3(in_channels, hidden_size),
            self.conv3x3(hidden_size, hidden_size),
            self.conv3x3(hidden_size, hidden_size),
            self.conv3x3(hidden_size, hidden_size),
        )

        self.classifier = nn.Linear(hidden_size, out_features)

    def forward(self, inputs, params=None):
        features = self.features(inputs)
        features = features.view((features.size(0), -1))
        logits = self.classifier(features)
        return logits

    def conv3x3(self, in_channels, out_channels, **kwargs):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1, **kwargs),
            nn.BatchNorm2d(out_channels, momentum=1.0, track_running_stats=False),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )

# %%
def get_accuracy(logits, targets):
    """Compute the accuracy (after adaptation) of MAML on the test/query points
    Parameters
    ----------
    logits : `torch.FloatTensor` instance
        Outputs/logits of the model on the query points. This tensor has shape
        `(num_examples, num_classes)`.
    targets : `torch.LongTensor` instance
        A tensor containing the targets of the query points. This tensor has 
        shape `(num_examples,)`.
    Returns
    -------
    accuracy : `torch.FloatTensor` instance
        Mean accuracy on the query points
    """
    _, predictions = torch.max(logits, dim=-1)
    return torch.mean(predictions.eq(targets).float())

# %%
class MAML(pl.LightningModule):
    def __init__(self, model):
        super().__init__()
        self.model = model
        self.accuracy = get_accuracy
        self.automatic_optimization = False
    
    def forward(self, x):
        return self.model(x)
    def training_step(self, batch, batch_idx, optimizer_idx):
        meta_optimizer, inner_optimizer = self.optimizers()
        meta_optimizer = meta_optimizer.optimizer
        inner_optimizer = inner_optimizer.optimizer
        
        train_inputs, train_targets = batch['train']
        test_inputs, test_targets = batch['test']
        
        batch_size = train_inputs.shape[0]
        self.print(batch_size)
        outer_loss = torch.tensor(0., device=self.device)
        acc = torch.tensor(0., device=self.device)

        for task_idx, (train_input, train_target, test_input, test_target) in enumerate(
            zip(train_inputs, train_targets, test_inputs, test_targets)
        ):
            with higher.innerloop_ctx(self.model, inner_optimizer, copy_initial_weights=False) as (fmodel, diffopt):
                train_logit = fmodel(train_input)
                inner_loss = F.cross_entropy(train_logit, train_target)
                
                diffopt.step(inner_loss)
                
                test_logit = fmodel(test_input)
                outer_loss += F.cross_entropy(test_logit, test_target)
                
                with torch.no_grad():
                    preds = test_logit.softmax(dim=-1)
                    acc += torchmetrics.functional.accuracy(preds, test_target)
                

#                     self.print(self.accuracy(test_logit, test_target))
                    self.print(test_logit[0])
                    self.print(test_target[0])
                
        outer_loss.div_(batch_size)
        acc.div_(batch_size)
        self.log_dict({
                    'outer_loss': outer_loss,
                    'accuracy': acc
                }, prog_bar=True)
        
        self.manual_backward(outer_loss, meta_optimizer)
        
        return outer_loss
    
    def configure_optimizers(self):
        meta_optimizer = torch.optim.Adam(self.parameters(), lr=1e-3)
        inner_optimizer = torch.optim.SGD(self.parameters(), lr=1e-1)
        
        return [meta_optimizer, inner_optimizer]

# %%
class OmniglotDataModule(pl.LightningDataModule):
    def __init__(
        self,
        data_dir: str,
        shots: int,
        ways: int,
        shuffle_ds: bool,
        test_shots: int,
        meta_train: bool,
        download: bool,
        batch_size: str,
        shuffle: bool,
        num_workers: int):
        super().__init__()
        self.data_dir = data_dir
        self.shots = shots
        self.ways = ways
        self.shuffle_ds = shuffle_ds
        self.test_shots = test_shots
        self.meta_train = meta_train
        self.download = download
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.num_workers = num_workers
    
    def setup(self, stage=None):
        self.task_dataset = omniglot(
            self.data_dir,
            shots=self.shots,
            ways=self.ways,
            shuffle=self.shuffle_ds,
            test_shots=self.test_shots,
            meta_train=self.meta_train,
            download=self.download
        )
    def train_dataloader(self):
        return BatchMetaDataLoader(
            self.task_dataset,
            batch_size=self.batch_size,
            shuffle=self.shuffle,
            num_workers=self.num_workers
        )

# %%
dm = OmniglotDataModule(
        "data",
        shots=5,
        ways=1,
        shuffle_ds=True,
        test_shots=15,
        meta_train=True,
        download=True,
        batch_size=16,
        shuffle=True,
        num_workers=8,
)

# %%
dm.setup()
batch =dm.train_dataloader()

# %%
batch = next(iter(batch))
# Out:
# /home/ojass/anaconda3/envs/jax/lib/python3.9/site-packages/torchvision/transforms/functional.py:942: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# /home/ojass/anaconda3/envs/jax/lib/python3.9/site-packages/torchvision/transforms/functional.py:942: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# /home/ojass/anaconda3/envs/jax/lib/python3.9/site-packages/torchvision/transforms/functional.py:942: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# /home/ojass/anaconda3/envs/jax/lib/python3.9/site-packages/torchvision/transforms/functional.py:942: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# /home/ojass/anaconda3/envs/jax/lib/python3.9/site-packages/torchvision/transforms/functional.py:942: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# /home/ojass/anaconda3/envs/jax/lib/python3.9/site-packages/torchvision/transforms/functional.py:942: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# /home/ojass/anaconda3/envs/jax/lib/python3.9/site-packages/torchvision/transforms/functional.py:942: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# /home/ojass/anaconda3/envs/jax/lib/python3.9/site-packages/torchvision/transforms/functional.py:942: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(

# %%
batch['train'][0].shape
# Out:
# torch.Size([16, 5, 1, 28, 28])

# %%
model = MAML(model=ConvolutionalNeuralNetwork(1, 5, hidden_size=64))

# %%
logger = WandbLogger(
    project='maml'
)
trainer = Trainer(
        profiler='simple',
        max_epochs=100,
        fast_dev_run=False,
        num_sanity_val_steps=2, gpus=1, #logger=logger
    )
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    trainer.fit(model, datamodule=dm)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type                       | Params
# -----------------------------------------------------
# 0 | model | ConvolutionalNeuralNetwork | 112 K
# -----------------------------------------------------
# 112 K     Trainable params
# 0         Non-trainable params
# 112 K     Total params
# 0.449     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# 16
# tensor([ 7.9036, -0.8018, -1.9563, -1.6999, -1.8623], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.0959, -0.9833, -1.8878, -2.1419, -1.5133], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.8777, -1.0457, -1.9666, -1.6909, -1.3560], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.9689, -1.2400, -2.2301, -2.8620, -1.6561], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.1171, -1.5409, -1.8214, -1.1864, -1.1540], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.6583, -1.2810, -2.2873, -1.6743, -1.4706], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.6766, -1.3880, -2.1270, -2.6105, -1.4791], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.9662, -1.4132, -2.1438, -2.9371, -1.2142], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 9.8331, -1.8331, -2.5055, -2.3655, -1.8824], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.9330, -0.9309, -2.0223, -2.3454, -1.5077], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.0844, -1.2109, -2.2669, -2.0198, -1.1469], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.5022, -0.9990, -1.7642, -1.5555, -1.0325], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.2653, -1.0615, -2.2238, -2.5371, -1.4345], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.1243, -1.4048, -1.6624, -1.8287, -1.1183], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.1081, -1.4186, -2.0036, -2.0622, -1.8171], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.6920, -0.4354, -1.5546, -1.9939, -1.0697], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# 16
# tensor([ 6.9387, -1.0132, -1.9733, -1.7400, -1.6216], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4696, -1.0870, -1.8024, -2.4050, -1.2916], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.3656, -1.0602, -1.6346, -3.2456, -1.1280], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 4.0872, -0.7557, -1.2246, -1.0439, -0.5274], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.6055, -1.1757, -2.1087, -1.9317, -1.2893], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.6520, -1.3719, -1.6559, -2.8015, -1.3389], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.0816, -0.9615, -2.2124, -2.7239, -1.7352], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.9351, -1.5030, -1.6625, -2.1441, -1.3741], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4098, -1.3032, -2.1563, -1.8935, -1.2330], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.5684, -1.1706, -2.1338, -2.4703, -1.9412], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.0477, -0.8326, -2.0577, -2.8474, -1.0268], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.9723, -0.7759, -2.2075, -1.4518, -1.2109], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.5487, -0.8245, -2.0344, -2.6624, -1.6027], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.9593, -0.6618, -1.8871, -2.2706, -0.7351], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.0831, -0.9503, -1.8022, -2.3798, -2.0242], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.0758, -0.9157, -2.1850, -1.8780, -1.5640], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# 16
# tensor([ 8.1596, -0.7457, -2.5649, -2.8475, -1.1670], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.6104, -0.9237, -2.0885, -2.8119, -1.5696], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.7095, -1.0938, -2.0143, -1.9097, -1.1376], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.3350, -0.8810, -1.7189, -2.3343, -1.4558], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.6365, -1.4198, -1.8814, -1.6695, -1.5781], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.5461, -1.0632, -2.4826, -2.8188, -1.3744], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4106, -1.2936, -2.0665, -1.8589, -1.4707], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.2005, -0.7300, -1.7724, -1.7184, -1.9013], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4637, -1.1850, -2.2935, -2.0015, -1.2560], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.3438, -1.0283, -1.6174, -2.3321, -1.8041], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.5387, -1.4745, -2.0052, -2.6055, -1.6774], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.7776, -1.0477, -2.0216, -1.6382, -1.2423], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4535, -1.6712, -2.3675, -2.0283, -0.7291], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.8825, -0.9761, -2.1315, -1.9990, -1.3076], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.7059, -1.0877, -2.0241, -1.7946, -1.6843], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 3.4164, -0.6514, -0.9802, -0.6940, -0.6790], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# 16
# tensor([ 9.3862, -0.8204, -2.4661, -2.3022, -1.3201], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.8191, -0.5585, -2.1499, -2.4779, -1.1155], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.2989, -1.1660, -1.8818, -1.9647, -1.6553], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.9036, -0.7292, -1.9222, -2.1063, -0.9094], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 9.6936, -1.1783, -2.3301, -3.0152, -2.8791], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.9887, -1.1317, -2.3534, -1.7203, -0.9758], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.1626, -1.5938, -2.2252, -2.8316, -1.0592], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4887, -1.1405, -1.8899, -2.1982, -1.6795], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.2898, -1.3366, -1.8587, -1.7263, -0.9800], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 9.3564, -1.0547, -2.1642, -2.7309, -1.6829], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.8109, -0.8335, -2.5620, -2.0136, -1.7878], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.1224, -0.8760, -1.5874, -2.5265, -0.9470], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.3683, -0.6295, -2.0169, -2.2982, -0.9304], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.3860, -0.7985, -2.0857, -2.1369, -1.3140], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.3126, -0.6458, -2.1519, -3.0722, -0.7120], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.8013, -1.1514, -2.1141, -2.3690, -1.3273], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# 16
# tensor([ 8.9371, -1.3735, -2.3649, -2.4306, -1.5404], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 9.4246, -1.6507, -1.9186, -2.6765, -2.0810], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.0990, -0.8282, -1.5717, -2.3268, -1.5708], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.1389, -0.9710, -1.7042, -2.4800, -1.5300], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.3099, -0.9815, -1.9302, -2.2131, -1.0454], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.6374, -1.2636, -1.6810, -1.7212, -1.2651], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.8524, -1.3086, -2.3806, -2.1702, -1.2637], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.6708, -1.1426, -2.1719, -1.6753, -1.1494], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.0697, -1.0463, -1.9405, -2.0834, -0.7377], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([10.9272, -1.4796, -1.8756, -3.5450, -1.6487], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.6210, -0.6509, -1.5868, -2.3932, -0.7964], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 9.5859, -1.0120, -2.5748, -2.4979, -1.8775], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.5523, -0.7645, -1.1227, -1.6833, -1.7033], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.5007, -0.9342, -1.9439, -1.7610, -1.5406], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.6364, -1.3617, -1.7650, -2.2894, -1.3198], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 9.3958, -1.4833, -2.3279, -2.9236, -0.7772], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# 16
# tensor([ 7.5000, -0.8732, -1.9257, -2.0888, -1.1720], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.1447, -1.0470, -2.3286, -2.4042, -1.1380], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.5332, -1.0044, -1.5180, -2.5169, -2.0110], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.7120, -0.7402, -2.0907, -2.3970, -1.4554], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4421, -0.9810, -1.6108, -2.5021, -1.0361], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.6660, -0.6489, -1.5812, -2.9385, -1.0023], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.9048, -1.2322, -2.2103, -2.0772, -1.2994], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.0108, -1.3440, -1.9854, -1.8288, -0.7786], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.3018, -0.9965, -1.2132, -2.3320, -1.8255], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.0761, -0.8272, -1.6931, -2.3261, -1.1697], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4006, -0.8438, -1.7221, -2.8284, -0.8914], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.1426, -0.7485, -1.7401, -1.9682, -0.9984], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.5577, -1.0452, -2.1933, -2.1592, -1.7127], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.8516, -1.5409, -1.9889, -1.6742, -1.4985], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.1558, -0.9306, -2.0033, -1.9671, -0.9147], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.2056, -0.2982, -1.1820, -2.6701, -1.0009], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# 16
# tensor([ 7.4481, -0.8492, -1.7485, -2.4083, -1.4265], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.5598, -0.7688, -1.8178, -2.5597, -0.9372], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.0228, -0.6797, -1.9779, -2.1713, -0.9028], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.1820, -1.2462, -1.7647, -2.6281, -1.3314], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.5805, -1.1374, -1.8836, -1.2927, -1.2593], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.0488, -1.2405, -2.0935, -2.5149, -0.8100], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4975, -0.6589, -1.8343, -2.1271, -1.6822], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.2151, -1.5835, -2.3281, -1.7815, -1.5040], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.0800, -0.7114, -1.8962, -2.0684, -1.5065], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.1339, -1.0523, -1.6552, -1.9602, -1.7248], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.8680, -1.3102, -2.4525, -1.9484, -1.1929], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4347, -1.0096, -2.0634, -1.8129, -1.3722], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.7443, -0.8850, -2.0977, -2.8600, -0.8245], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.9917, -0.9836, -1.7530, -2.6922, -1.1486], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.9071, -0.6124, -1.7509, -1.8873, -1.3796], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.2936, -0.5722, -1.6804, -2.5920, -0.9676], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# 16
# tensor([ 6.6799, -0.9843, -1.9272, -1.7653, -1.2221], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.7871, -0.6619, -1.9542, -2.8892, -1.1023], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.2445, -1.2233, -1.7573, -2.1302, -1.8026], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.1045, -1.0239, -1.8139, -2.0600, -1.1814], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.0054, -0.5081, -1.3051, -2.3268, -1.1752], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.4495, -1.1358, -2.1356, -1.4907, -1.0977], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.0976, -0.4269, -1.8564, -2.4595, -0.7681], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.6537, -0.9214, -2.5350, -1.6983, -1.0464], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.2242, -0.8534, -2.3207, -2.2609, -0.7216], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.9129, -1.3146, -2.2085, -2.6216, -1.8214], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.0356, -1.1817, -2.3284, -1.5132, -1.9752], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 4.1740, -0.5496, -0.9402, -0.8380, -0.6585], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.9968, -1.2952, -2.1018, -2.6924, -1.2140], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.6626, -0.5438, -2.1299, -1.7249, -1.4971], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.8332, -0.8823, -2.0372, -2.6970, -1.3252], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.2128, -0.8994, -2.1196, -2.4403, -1.4565], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# 16
# tensor([ 7.5375, -1.1576, -1.7630, -2.8396, -0.8851], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.5817, -1.1252, -1.6185, -2.7600, -1.8109], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.0592, -1.2328, -1.8740, -2.5514, -1.3452], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 3.5406, -0.6350, -1.2112, -0.8670, -0.3948], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.5884, -0.9105, -1.7418, -1.9285, -0.5915], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.2339, -0.7002, -1.6731, -2.2107, -1.1913], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 9.3464, -0.9692, -1.9304, -2.3102, -2.4014], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.5558, -1.2470, -2.5496, -2.1285, -0.7742], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.6742, -0.4528, -1.8652, -2.2134, -1.0661], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.7128, -1.3175, -2.5163, -2.1136, -1.2863], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4915, -1.1448, -2.3402, -2.3139, -1.0728], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 9.5426, -1.3313, -2.1731, -2.8534, -1.6783], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 9.8523, -1.4653, -2.4432, -2.7727, -1.9115], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.8927, -0.8494, -1.8307, -2.1595, -1.2306], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.1212, -0.6681, -1.8248, -2.0115, -1.1001], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4890, -1.1385, -2.0869, -2.4063, -0.9455], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# 16
# tensor([ 7.1895, -1.3063, -2.0770, -2.1294, -1.2135], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.6135, -1.2232, -1.8296, -1.6888, -1.2631], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.8663, -0.9432, -1.8875, -2.7364, -0.8843], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.0778, -1.0663, -1.4934, -2.6017, -1.4302], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.0140, -1.0758, -1.4064, -1.9259, -1.7127], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.8413, -0.5223, -1.8907, -1.9480, -1.2897], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 9.2160, -1.6573, -1.7483, -2.7562, -2.0521], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.5913, -1.0108, -2.2234, -3.1929, -0.9284], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.8405, -0.9314, -1.7686, -2.0355, -1.1315], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.3141, -1.1995, -1.8029, -2.5139, -1.5300], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.7905, -0.9248, -1.5004, -1.8821, -0.9981], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.0946, -1.5831, -1.9896, -2.3192, -1.8361], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4329, -0.7516, -1.7781, -2.3869, -2.0234], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.4414, -0.7088, -1.6438, -1.9672, -2.3228], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.5833, -0.9685, -1.7119, -1.8752, -1.9151], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.3926, -1.0844, -1.8449, -1.9426, -1.2217], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# 16
# tensor([ 7.9723, -1.3091, -2.2626, -2.2978, -1.4323], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.2463, -0.9873, -1.7346, -1.9166, -1.1813], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.3159, -1.0345, -1.9085, -2.4430, -0.9631], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.8155, -1.3278, -2.3992, -1.7898, -1.4696], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.5015, -1.4973, -2.0708, -1.9646, -1.1153], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.5353, -1.0365, -2.3592, -2.1930, -0.6847], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.0496, -0.6328, -1.6187, -2.5893, -0.9943], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.3667, -1.1087, -2.3432, -2.5462, -1.5631], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.0780, -0.6741, -1.6813, -3.0894, -0.7873], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.1072, -1.1490, -2.2647, -2.0364, -1.2118], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.2254, -1.0344, -1.5853, -2.2808, -1.1794], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.1266, -1.7900, -2.1549, -2.0677, -1.1193], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.9556, -1.5052, -2.5075, -2.2551, -1.5236], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.3428, -1.0438, -1.7533, -2.7730, -0.8074], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4970, -0.7558, -1.8637, -2.9815, -1.1596], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.2149, -0.8867, -2.2076, -1.5319, -1.7651], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# 16
# tensor([ 7.8324, -1.0154, -1.4139, -2.4014, -1.4288], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.6084, -1.0839, -1.7133, -1.7631, -1.6781], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4283, -0.6448, -1.9454, -2.5473, -1.3397], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.4180, -0.4261, -1.1551, -1.9584, -1.4186], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.0724, -0.7935, -1.8813, -2.3583, -1.1814], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.6386, -1.5838, -1.9340, -2.1092, -1.4146], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.2233, -0.8411, -1.3000, -1.6438, -1.1848], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.6701, -1.1230, -1.8604, -2.6198, -1.8591], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4384, -0.7416, -1.7130, -2.8539, -1.1192], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.8078, -1.4158, -2.1266, -2.2993, -1.8547], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.8547, -1.2152, -1.7318, -1.6897, -1.9265], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.2372, -0.8542, -2.7522, -2.4248, -0.9831], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.8241, -0.8482, -2.3036, -2.5164, -1.3688], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.6829, -1.2558, -1.6324, -2.7060, -1.4968], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.8723, -0.7190, -2.0042, -1.4065, -1.6359], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.0123, -0.9373, -1.5244, -2.0301, -1.1377], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# 16
# tensor([ 6.7113, -0.9537, -1.5041, -1.9026, -1.0682], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.9858, -1.0229, -2.1489, -2.2063, -1.1258], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.9294, -0.8146, -2.1415, -2.0993, -1.7897], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4009, -1.3414, -2.0488, -2.2490, -1.7926], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.3518, -1.0387, -1.9076, -3.2293, -0.7687], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.3707, -1.2994, -2.3692, -2.1528, -1.1272], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.8992, -0.9313, -2.1546, -2.2142, -0.9046], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.5459, -1.1065, -2.3038, -2.1709, -1.3613], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.1147, -1.1293, -2.0349, -1.7260, -1.6473], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.7311, -0.7992, -1.7843, -2.1191, -0.8747], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.8760, -1.4438, -1.7259, -2.3189, -0.8602], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.7427, -1.0192, -2.5153, -3.5132, -0.8376], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.1423, -0.8837, -1.7812, -1.7619, -1.4619], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.8151, -1.1622, -1.9604, -2.3175, -0.8201], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.5829, -1.1127, -1.9733, -2.3349, -1.5092], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.1271, -0.9274, -1.3153, -2.1416, -1.8329], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# 16
# tensor([ 7.4338, -1.0227, -2.1668, -1.9498, -1.2736], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.4228, -1.0516, -2.2821, -2.6663, -1.0098], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.1976, -0.7676, -2.0174, -2.2243, -1.4015], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.5822, -0.9414, -1.8425, -2.3757, -1.2205], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.2510, -1.3525, -1.7270, -2.2019, -1.5465], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.0810, -0.8633, -1.7238, -2.0945, -0.9722], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.5542, -0.6134, -1.8015, -2.2006, -0.9792], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.0848, -1.2084, -1.9822, -2.5364, -0.8015], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.6871, -1.4869, -2.4720, -2.8477, -0.8025], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.5654, -0.6412, -1.8335, -2.4498, -1.4141], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 9.8027, -1.7233, -1.9627, -2.2012, -2.3451], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.6367, -1.0410, -1.8548, -2.6967, -1.7889], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.9439, -0.7333, -1.5875, -2.2537, -1.3872], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.9806, -0.8166, -2.1158, -2.3696, -1.2733], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.5264, -0.7252, -2.0998, -2.1598, -1.2409], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.8849, -1.1868, -1.8950, -2.3801, -0.9217], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# 16
# tensor([ 6.8988, -0.8864, -2.0726, -1.3611, -0.9352], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.7589, -1.0352, -1.8669, -1.9559, -1.0460], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.8109, -1.2141, -2.0208, -2.1599, -1.7410], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.2919, -1.3523, -2.2139, -1.3353, -1.7139], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.8289, -0.8802, -2.4086, -2.0192, -1.0117], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.3691, -0.8636, -2.0799, -2.3490, -1.5978], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.7372, -0.8406, -2.1457, -2.7533, -1.2736], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.1167, -1.4004, -1.8143, -2.1996, -1.3669], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4423, -0.9589, -2.1302, -2.2163, -0.7662], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.6371, -0.9703, -1.8073, -2.3881, -1.5101], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.5010, -1.3292, -1.7408, -2.4629, -1.1482], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.3628, -1.3419, -1.8904, -2.6710, -0.6554], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.7017, -1.0045, -2.1927, -2.3360, -1.2142], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.5452, -1.4702, -2.1968, -3.0331, -1.0904], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.0146, -0.5651, -1.7430, -2.3808, -0.9573], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.8188, -1.2844, -1.9954, -1.9772, -0.9818], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# 16
# tensor([ 7.5849, -0.9214, -1.8809, -1.7482, -1.1721], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.1136, -1.3342, -1.8875, -2.0901, -2.2449], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.5396, -0.9701, -1.8581, -1.8423, -0.9398], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.5887, -0.9624, -2.0793, -2.6633, -1.0714], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.2307, -1.0176, -1.9928, -2.3029, -1.6365], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.6982, -0.4699, -1.3721, -2.5397, -1.0975], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.9162, -1.0938, -1.8564, -1.2773, -1.3682], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4602, -0.6163, -1.6029, -2.3218, -1.2220], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4722, -0.6998, -1.7676, -2.0204, -1.3765], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.0574, -1.2211, -1.8278, -3.0434, -0.8272], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.1394, -0.6278, -2.2801, -2.1873, -1.2267], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.9694, -0.7473, -1.9061, -1.9926, -1.3256], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 9.1010, -1.8213, -2.8572, -1.9004, -1.7112], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.3312, -1.0999, -1.9077, -2.2470, -1.1985], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.1728, -1.0154, -2.0190, -2.2645, -1.4434], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.6552, -1.2614, -2.0170, -1.9504, -1.5839], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# 16
# tensor([ 7.3047, -0.9242, -1.8079, -2.4720, -0.8410], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.0110, -1.3293, -2.0951, -2.1139, -1.3659], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.1818, -0.8697, -2.1980, -2.3217, -0.4186], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.5885, -0.9366, -1.5721, -2.1823, -1.4136], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.6532, -0.9784, -2.0967, -2.2856, -1.1000], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.0497, -0.8663, -1.7916, -2.4378, -0.8930], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.1112, -0.6504, -1.5225, -2.6468, -2.1316], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.8224, -0.8116, -1.6455, -1.7310, -1.2554], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 9.3618, -1.2613, -2.5256, -2.9835, -1.7536], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.2062, -0.4857, -1.6564, -2.3312, -0.7794], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.3064, -0.6374, -1.4183, -1.7408, -1.1448], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.5352, -1.0839, -1.7171, -2.5577, -0.9606], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.4591, -0.9954, -2.1559, -2.8584, -1.3402], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 6.6636, -1.7433, -1.8179, -1.7865, -1.0743], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 8.2538, -0.8179, -2.4203, -2.1697, -1.7023], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
# tensor([ 7.4985, -1.0578, -1.9076, -1.3660, -1.4477], device='cuda:0',
#        requires_grad=True)
# tensor(0, device='cuda:0')
